9 MB/s eta 0:00:04
#    ---------------------------------- ---- 295.4/331.8 MB 10.9 MB/s eta 0:00:04
#    ---------------------------------- ---- 297.8/331.8 MB 10.9 MB/s eta 0:00:04
#    ----------------------------------- --- 300.2/331.8 MB 10.9 MB/s eta 0:00:03
#    ----------------------------------- --- 302.5/331.8 MB 10.9 MB/s eta 0:00:03
#    ----------------------------------- --- 304.9/331.8 MB 10.9 MB/s eta 0:00:03
#    ------------------------------------ -- 307.2/331.8 MB 10.9 MB/s eta 0:00:03
#    ------------------------------------ -- 309.6/331.8 MB 10.9 MB/s eta 0:00:03
#    ------------------------------------ -- 311.7/331.8 MB 10.9 MB/s eta 0:00:02
#    ------------------------------------ -- 314.3/331.8 MB 10.9 MB/s eta 0:00:02
#    ------------------------------------- - 316.4/331.8 MB 10.9 MB/s eta 0:00:02
#    ------------------------------------- - 318.5/331.8 MB 10.9 MB/s eta 0:00:02
#    ------------------------------------- - 320.6/331.8 MB 10.9 MB/s eta 0:00:02
#    ------------------------------------- - 322.7/331.8 MB 10.9 MB/s eta 0:00:01
#    --------------------------------------  325.3/331.8 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  327.7/331.8 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  330.0/331.8 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.8 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.8 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.8 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.8 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.8 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.8 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.8 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------- 331.8/331.8 MB 10.3 MB/s eta 0:00:00
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    --------- ------------------------------ 1.3/5.5 MB 6.7 MB/s eta 0:00:01
#    ------------------------ --------------- 3.4/5.5 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 7.7 MB/s eta 0:00:00
# Downloading protobuf-6.32.0-cp310-abi3-win_amd64.whl (435 kB)
# Installing collected packages: protobuf, tensorboard, tensorflow
#
#   Attempting uninstall: protobuf
#
#     Found existing installation: protobuf 3.20.3
#
#     Uninstalling protobuf-3.20.3:
#
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#       Successfully uninstalled protobuf-3.20.3
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#    ---------------------------------------- 0/3 [protobuf]
#   Attempting uninstall: tensorboard
#    ---------------------------------------- 0/3 [protobuf]
#    ------------- -------------------------- 1/3 [tensorboard]
#     Found existing installation: tensorboard 2.19.0
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#     Uninstalling tensorboard-2.19.0:
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#       Successfully uninstalled tensorboard-2.19.0
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    ------------- -------------------------- 1/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
# ...
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    -------------------------- ------------- 2/3 [tensorflow]
#    ---------------------------------------- 3/3 [tensorflow]
#
# Successfully installed protobuf-6.32.0 tensorboard-2.20.0 tensorflow-2.20.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.16.0 requires protobuf<4,>=3.12, but you have protobuf 6.32.0 which is incompatible.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip uninstall tensorflow keras keras-preprocessing -y
# Out:
# Found existing installation: tensorflow 2.20.0
# Uninstalling tensorflow-2.20.0:
#   Successfully uninstalled tensorflow-2.20.0
# Found existing installation: keras 3.10.0
# Uninstalling keras-3.10.0:
#   Successfully uninstalled keras-3.10.0
# WARNING: Skipping keras-preprocessing as it is not installed.

# %%
# !pip install --upgrade pip setuptools wheel
# !pip install tensorflow==2.15.0
# Out:
# Requirement already satisfied: pip in d:\pythontemp\anaconda3\lib\site-packages (25.1.1)
# Collecting pip
#   Using cached pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools in d:\pythontemp\anaconda3\lib\site-packages (75.1.0)
# Collecting setuptools
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: wheel in d:\pythontemp\anaconda3\lib\site-packages (0.44.0)
# Collecting wheel
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Using cached pip-25.2-py3-none-any.whl (1.8 MB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: To modify pip, please run the following command:
# D:\pythontemp\anaconda3\python.exe -m pip install --upgrade pip setuptools wheel
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Collecting tensorflow-intel==2.15.0 (from tensorflow==2.15.0)
#   Downloading tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (24.1)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading protobuf-4.25.8-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.14.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\pythontemp\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.74.0)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading google_auth_oauthlib-1.2.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown>=2.6.8 in d:\pythontemp\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\pythontemp\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\pythontemp\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\pythontemp\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\pythontemp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\pythontemp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\pythontemp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\pythontemp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\pythontemp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\pythontemp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2024.8.30)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\pythontemp\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.4.8)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\pythontemp\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.44.0)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\pythontemp\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.1.3)
# Downloading tensorflow-2.15.0-cp311-cp311-win_amd64.whl (2.1 kB)
# Downloading tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl (300.9 MB)
#    ---------------------------------------- 0.0/300.9 MB ? eta -:--:--
#    ---------------------------------------- 2.1/300.9 MB 10.7 MB/s eta 0:00:29
#     --------------------------------------- 4.5/300.9 MB 10.8 MB/s eta 0:00:28
#     --------------------------------------- 6.0/300.9 MB 9.7 MB/s eta 0:00:31
#     --------------------------------------- 7.3/300.9 MB 9.1 MB/s eta 0:00:33
#    - -------------------------------------- 8.9/300.9 MB 8.5 MB/s eta 0:00:35
#    - -------------------------------------- 10.0/300.9 MB 8.0 MB/s eta 0:00:37
#    - -------------------------------------- 11.3/300.9 MB 7.6 MB/s eta 0:00:39
#    - -------------------------------------- 13.1/300.9 MB 7.7 MB/s eta 0:00:38
#    -- ------------------------------------- 15.5/300.9 MB 8.0 MB/s eta 0:00:36
#    -- ------------------------------------- 17.6/300.9 MB 8.3 MB/s eta 0:00:35
#    -- ------------------------------------- 19.9/300.9 MB 8.4 MB/s eta 0:00:34
#    -- ------------------------------------- 22.0/300.9 MB 8.5 MB/s eta 0:00:33
#    --- ------------------------------------ 24.4/300.9 MB 8.8 MB/s eta 0:00:32
#    --- ------------------------------------ 26.7
1 MB/s eta 0:00:09
#    ----------------------------- ---------- 223.3/300.9 MB 9.1 MB/s eta 0:00:09
#    ------------------------------ --------- 225.7/300.9 MB 9.1 MB/s eta 0:00:09
#    ------------------------------ --------- 228.1/300.9 MB 9.1 MB/s eta 0:00:08
#    ------------------------------ --------- 230.2/300.9 MB 9.1 MB/s eta 0:00:08
#    ------------------------------ --------- 232.3/300.9 MB 9.1 MB/s eta 0:00:08
#    ------------------------------- -------- 234.6/300.9 MB 9.2 MB/s eta 0:00:08
#    ------------------------------- -------- 236.7/300.9 MB 9.2 MB/s eta 0:00:08
#    ------------------------------- -------- 239.1/300.9 MB 9.2 MB/s eta 0:00:07
#    -------------------------------- ------- 241.4/300.9 MB 9.2 MB/s eta 0:00:07
#    -------------------------------- ------- 243.8/300.9 MB 9.2 MB/s eta 0:00:07
#    -------------------------------- ------- 246.2/300.9 MB 9.2 MB/s eta 0:00:06
#    --------------------------------- ------ 248.8/300.9 MB 9.2 MB/s eta 0:00:06
#    --------------------------------- ------ 250.6/300.9 MB 9.2 MB/s eta 0:00:06
#    --------------------------------- ------ 252.7/300.9 MB 9.2 MB/s eta 0:00:06
#    --------------------------------- ------ 254.5/300.9 MB 9.2 MB/s eta 0:00:06
#    ---------------------------------- ----- 256.1/300.9 MB 9.2 MB/s eta 0:00:05
#    ---------------------------------- ----- 258.2/300.9 MB 9.2 MB/s eta 0:00:05
#    ---------------------------------- ----- 260.6/300.9 MB 9.2 MB/s eta 0:00:05
#    ---------------------------------- ----- 262.7/300.9 MB 9.2 MB/s eta 0:00:05
#    ----------------------------------- ---- 264.5/300.9 MB 9.2 MB/s eta 0:00:04
#    ----------------------------------- ---- 266.9/300.9 MB 9.2 MB/s eta 0:00:04
#    ----------------------------------- ---- 268.7/300.9 MB 9.3 MB/s eta 0:00:04
#    ----------------------------------- ---- 270.8/300.9 MB 9.3 MB/s eta 0:00:04
#    ------------------------------------ --- 273.4/300.9 MB 9.4 MB/s eta 0:00:03
#    ------------------------------------ --- 275.8/300.9 MB 9.4 MB/s eta 0:00:03
#    ------------------------------------ --- 278.1/300.9 MB 9.4 MB/s eta 0:00:03
#    ------------------------------------- -- 280.5/300.9 MB 9.4 MB/s eta 0:00:03
#    ------------------------------------- -- 282.9/300.9 MB 9.4 MB/s eta 0:00:02
#    ------------------------------------- -- 285.0/300.9 MB 9.4 MB/s eta 0:00:02
#    -------------------------------------- - 286.3/300.9 MB 9.4 MB/s eta 0:00:02
#    -------------------------------------- - 287.3/300.9 MB 9.3 MB/s eta 0:00:02
#    -------------------------------------- - 289.4/300.9 MB 9.3 MB/s eta 0:00:02
#    -------------------------------------- - 291.5/300.9 MB 9.3 MB/s eta 0:00:02
#    -------------------------------------- - 292.3/300.9 MB 9.3 MB/s eta 0:00:01
#    -------------------------------------- - 292.8/300.9 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  294.4/300.9 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  296.7/300.9 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------  298.8/300.9 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------  300.7/300.9 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------  300.7/300.9 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 300.9/300.9 MB 9.1 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------ --------- 1.3/1.7 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 6.2 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp311-cp311-win_amd64.whl (938 kB)
#    ---------------------------------------- 0.0/938.7 kB ? eta -:--:--
#    ---------------------------------------- 938.7/938.7 kB 8.7 MB/s eta 0:00:00
# Downloading protobuf-4.25.8-cp310-abi3-win_amd64.whl (413 kB)
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ------------- -------------------------- 1.8/5.5 MB 10.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.9/5.5 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 9.6 MB/s eta 0:00:00
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Downloading google_auth_oauthlib-1.2.2-py3-none-any.whl (19 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: tensorflow-estimator, rsa, protobuf, oauthlib, ml-dtypes, keras, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
#
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ----------------------------------------  0/12 [tensorflow-estimator]
#   Attempting uninstall: protobuf
#    ----------------------------------------  0/12 [tensorflow-estimator]
#    ------ ---------------------------------  2/12 [protobuf]
#     Found existing installation: protobuf 6.32.0
#    ------ ---------------------------------  2/12 [protobuf]
#     Uninstalling protobuf-6.32.0:
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#       Successfully uninstalled protobuf-6.32.0
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ------ ---------------------------------  2/12 [protobuf]
#    ---------- -----------------------------  3/12 [oauthlib]
#    ---------- -----------------------------  3/12 [oauthlib]
#   Attempting uninstall: ml-dtypes
#    ---------- -----------------------------  3/12 [oauthlib]
#    ------------- --------------------------  4/12 [ml-dtypes]
#     Found existing installation: ml_dtypes 0.5.1
#    ------------- --------------------------  4/12 [ml-dtypes]
#     Uninstalling ml_dtypes-0.5.1:
#    ------------- --------------------------  4/12 [ml-dtypes]
#       Successfully uninstalled ml_dtypes-0.5.1
#    ------------- --------------------------  4/12 [ml-dtypes]
#    ------------- --------------------------  4/12 [ml-dtypes]
#    ------------- --------------------------  4/12 [ml-dtypes]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    ---------------- -----------------------  5/12 [keras]
#    -------------------- -------------------  6/12 [requests-oauthlib]
#    ----------------------- ----------------  7/12 [google-auth]
#    ----------------------- ----------------  7/12 [google-auth]
#    ----------------------- ----------------  7/12 [google-auth]
#    ----------------------- ----------------  7/12 [google-auth]
#    ----------------------- ----------------  7/12 [google-auth]
#    -------------------------- -------------  8/12 [google-auth-oauthlib]
#   Attempting uninstall: tensorboard
#    -------------------------- -------------  8/12 [google-auth-oauthlib]
#     Found existing installation: tensorboard 2.20.0
#    -------------------------- -------------  8/12 [google-auth-oauthlib]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#     Uninstalling tensorboard-2.20.0:
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#       Successfully uninstalled tensorboard-2.20.0
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    ------------------------------ ---------  9/12 [tensorboard]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    --------------------------------- ------ 10/12 [tensorflow-intel]
#    ---------------------------------------- 12/12 [tensorflow]
#
# Successfully installed google-auth-2.40.3 google-auth-oauthlib-1.2.2 keras-2.15.0 ml-dtypes-0.2.0 oauthlib-3.3.1 protobuf-4.25.8 requests-oauthlib-2.0.0 rsa-4.9.1 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-intel-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.16.0 requires protobuf<4,>=3.12, but you have protobuf 4.25.8 which is incompatible.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import fnmatch
from collections import Counter
import zipfile
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D
# from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 2. 데이터 준비
# ➡️ 초기 1회만 실행
# - 이미지 확인 후 실행
# - 파일 병합 후 원래 폴더 항목들 삭제 됨

# %% [markdown]
# - 다른 파일의 압축 해제 및 데이터 병합

# %%
import os
import shutil

# 병합할 두 폴더 경로
# video_folders = ['./sVideoRA','./sVideoOL1', './sVideoOR1']  # 이미 압축 해제된 폴더들
# target_folder_path = './AVideo'     # 최종 병합할 위치
video_folders = ['./AAAVideo','./CVideo1','./CVideo2']  # 이미 압축 해제된 폴더들
target_folder_path = './AAAAVideo'     # 최종 병합할 위치

os.makedirs(target_folder_path, exist_ok=True)

# 두 폴더 순회하면서 파일 병합
for video_folder_path in video_folders: 
    for root, _, files in os.walk(video_folder_path):
        for file in files:
            source_file_path = os.path.join(root, file)
            target_file_path = os.path.join(target_folder_path, file)

            # 중복될 경우 파일명 뒤에 번호 붙이기
            if os.path.exists(target_file_path):
                base, extension = os.path.splitext(file)
                counter = 1
                new_file_name = f"{base}_{counter}{extension}"
                new_target_file_path = os.path.join(target_folder_path, new_file_name)
                while os.path.exists(new_target_file_path):
                    counter += 1
                    new_file_name = f"{base}_{counter}{extension}"
                    new_target_file_path = os.path.join(target_folder_path, new_file_name)
                target_file_path = new_target_file_path

            shutil.move(source_file_path, target_file_path)

print("video_folders가 병합되었습니다.")
# Out:
# video_folders가 병합되었습니다.

# %% [markdown]
# - 손상된 이미지 삭제

# %%
folder_path ='./s'

# 폴더 내의 모든 파일을 순회
for filename in os.listdir(folder_path):
    if filename.endswith(('.png', '.jpg', '.jpeg')):  # 이미지 파일 형식을 여기에 추가
        try:
            img = Image.open(os.path.join(folder_path, filename))  # 이미지 열기 시도
            img.verify()  # 이미지가 손상되었는지 확인
        except (IOError, SyntaxError) as e:
            print(f'{filename} is corrupted and will be deleted.')  # 손상된 이미지 파일명 출력
            os.remove(os.path.join(folder_path, filename))  # 손상된 이미지 삭제

# %% [markdown]
# # 3. 데이터의 분포 확인
# - go/right/left/stop 별 이미지 데이터의 개수 확인
#     - index: 090 ➡️ go
#     - index: 135 ➡️ right
#     - index: 045 ➡️ left
#     - index: 180 ➡️ stop

# %%
folder_path = './s'

# 이미지 파일 인덱스 집계를 위한 빈 Counter 객체 생성
index_counter = Counter()

# 삭제된 이미지를 제외한 폴더 내의 모든 파일을 순회
for filename in os.listdir(folder_path):
    if filename.endswith(('.png', '.jpg', '.jpeg')):  # 이미지 파일 형식을 여기에 추가
        index = filename[7:10]  # 파일명에서 인덱스 추출
            
        index_counter[index] += 1  # 추출된 인덱스에 대한 카운트 증가

# 인덱스별 이미지 개수 출력
for index, count in index_counter.items():
    print(f'Index: {index}, Count: {count}')
# Out:
# Index: 090, Count: 504
# Index: 135, Count: 246
# Index: 045, Count: 180

# %% [markdown]
# # 4. 데이터를 변수에 저장

# %%
data_dir = './s'
file_list = os.listdir(data_dir)
image_paths = [] # 이미지 경로를 저장하는 변수
steering_angles = [] # 이미지 각도를 저장하는 변수
pattern = "*.png" # .png 확장자 가진 파일만 취급

for filename in file_list:
    if fnmatch.fnmatch(filename, pattern):
        file_path = os.path.join(data_dir, filename)
        try:
            # 이미지 파일을 열어보려고 시도
            with Image.open(file_path) as img:
                # 파일이 성공적으로 열렸다면 리스트에 추가
                image_paths.append(file_path)
                angle = int(filename[7:10]) # 각도는 사진 데이터에서 7~9번째만 분리
                steering_angles.append(angle)
        except:
            # 파일 열기에 실패한 경우, 예외가 발생하고 해당 파일은 무시
            print(f"Failed to open {file_path}")

# 각도가 0인 이미지를 제거
image_paths = [path for path, angle in zip(image_paths, steering_angles) if angle != 0]
steering_angles = [angle for angle in steering_angles if angle != 0]

# 이후 과정은 동일하게 진행
image_index = 15
plt.imshow(Image.open(image_paths[image_index]))
print("image_path: %s" % image_paths[image_index])
print("steering_Angle: %d" % steering_angles[image_index])

df = pd.DataFrame()
df['ImagePath'] = image_paths
df['Angle'] = steering_angles
# Out:
# image_path: ./s\_00015_090.png
# steering_Angle: 90

# %% [markdown]
# # 5. 이미지 전처리 함수 생성

# %%
def preprocess_image(img_path):
    img = load_img(img_path, target_size=(66, 200))
    img = img_to_array(img)
    img = img / 255.0  # 정규화하여 [0, 1] 범위로 변환
    return img

# %% [markdown]
# # 6. 학습 / 검증 데이터 분리

# %%
images = np.array([preprocess_image(path) for path in df['ImagePath']])
angles = np.array(df['Angle'])

X_train, X_val, y_train, y_val = train_test_split(images, angles, test_size=0.2, random_state=42)

# %% [markdown]
# # 7. MobileNet 모델 선언

# %%
from tensorflow.keras.applications import MobileNet

# MobileNet 모델 선언 및 수정
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(66, 200, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1)(x)
model = Model(inputs=base_model.input, outputs=predictions)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %% [markdown]
# # 8. 학습 및 손실 계산
# - 최대 epoch를 30으로 설정, 일정 횟수동안 손실이 일정하다면 조기종료 되도록

# %%
from tensorflow.keras.callbacks import EarlyStopping

# 조기 종료 콜백 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# 모델 컴파일
model.compile(optimizer='adam', loss='mean_squared_error')

# 모델 훈련
history = model.fit(
    X_train, y_train, 
    epochs=30, 
    validation_data=(X_val, y_val),
    callbacks=[early_stopping],
    batch_size=32
)

# 모델 평가
loss = model.evaluate(X_val, y_val)
print(f"Validation Loss: {loss}")

# 모델 저장
model.save('./mobileNet_model_s.h5')
# Out:
# WARNING:tensorflow:From d:\pythontemp\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/30
# WARNING:tensorflow:From d:\pythontemp\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 24/24 [==============================] - 11s 239ms/step - loss: 1746.9487 - val_loss: 116680.4766
# Epoch 2/30
# 24/24 [==============================] - 7s 296ms/step - loss: 376.1561 - val_loss: 38547.0664
# Epoch 3/30
# 24/24 [==============================] - 7s 299ms/step - loss: 294.5707 - val_loss: 15605.0537
# Epoch 4/30
# 24/24 [==============================] - 6s 261ms/step - loss: 160.3965 - val_loss: 6678.1675
# Epoch 5/30
# 24/24 [==============================] - 7s 293ms/step - loss: 124.9321 - val_loss: 6140.9863
# Epoch 6/30
# 24/24 [==============================] - 6s 241ms/step - loss: 100.4404 - val_loss: 3017.3193
# Epoch 7/30
# 24/24 [==============================] - 7s 289ms/step - loss: 128.2779 - val_loss: 2922.4651
# Epoch 8/30
# 24/24 [==============================] - 6s 255ms/step - loss: 105.5833 - val_loss: 2160.5239
# Epoch 9/30
# 24/24 [==============================] - 8s 318ms/step - loss: 106.2227 - val_loss: 1334.7461
# Epoch 10/30
# 24/24 [==============================] - 6s 265ms/step - loss: 77.2526 - val_loss: 655.1862
# Epoch 11/30
# 24/24 [==============================] - 7s 315ms/step - loss: 54.9995 - val_loss: 687.5226
# Epoch 12/30
# 24/24 [==============================] - 6s 252ms/step - loss: 46.4798 - val_loss: 460.9261
# Epoch 13/30
# 24/24 [==============================] - 7s 286ms/step - loss: 35.3403 - val_loss: 446.4728
# Epoch 14/30
# 24/24 [==============================] - 7s 290ms/step - loss: 34.3980 - val_loss: 441.3703
# Epoch 15/30
# 24/24 [==============================] - 7s 268ms/step - loss: 44.6292 - val_loss: 344.0853
# Epoch 16/30
# 24/24 [==============================] - 8s 322ms/step - loss: 54.1395 - val_loss: 314.3961
# Epoch 17/30
# 24/24 [==============================] - 8s 331ms/step - loss: 38.5781 - val_loss: 431.1527
# Epoch 18/30
# 24/24 [==============================] - 8s 327ms/step - loss: 31.0863 - val_loss: 401.4473
# Epoch 19/30
# 24/24 [==============================] - 7s 311ms/step - loss: 21.9619 - val_loss: 357.0956
# Epoch 20/30
# 24/24 [==============================] - 8s 317ms/step - loss: 24.9277 - val_loss: 273.6553
# Epoch 21/30
# 24/24 [==============================] - 8s 317ms/step - loss: 34.2681 - val_loss: 259.3285
# Epoch 22/30
# 24/24 [==============================] - 9s 379ms/step - loss: 21.8571 - val_loss: 224.2688
# Epoch 23/30
# 24/24 [==============================] - 9s 373ms/step - loss: 50.5853 - val_loss: 258.8687
# Epoch 24/30
# 24/24 [==============================] - 9s 360ms/step - loss: 33.1683 - val_loss: 331.0757
# Epoch 25/30
# 24/24 [==============================] - 10s 436ms/step - loss: 29.0800 - val_loss: 259.2830
# Epoch 26/30
# 24/24 [==============================] - 10s 400ms/step - loss: 39.0852 - val_loss: 352.0647
# Epoch 27/30
# 24/24 [==============================] - 9s 390ms/step - loss: 27.9269 - val_loss: 298.1838
# Epoch 28/30
# 24/24 [==============================] - 10s 414ms/step - loss: 35.9116 - val_loss: 276.9182
# Epoch 29/30
# 24/24 [==============================] - 10s 411ms/step - loss: 33.1457 - val_loss: 274.7055
# Epoch 30/30
# 24/24 [==============================] - 10s 427ms/step - loss: 33.7114 - val_loss: 223.1067
# 6/6 [==============================] - 1s 116ms/step - loss: 223.1067
# Validation Loss: 223.106689453125
# d:\pythontemp\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # 9. 손실 시각화

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# # 10. 데이터 예측 시각화

# %%
# 모델 로드
model = tf.keras.models.load_model('./mobileNet_model_s.h5')

# 예시 이미지 4개에 대한 실제 값과 예측값 보여주기
example_indices = np.random.choice(len(df), 4, replace=False)
example_images = [preprocess_image(df['ImagePath'].iloc[idx]) for idx in example_indices]
example_images_array = np.array(example_images)
example_angles = df['Angle'].iloc[example_indices].values

# 예측 수행
predicted_angles = model.predict(example_images_array)

# 실제 값과 예측값 출력
for i in range(4):
    plt.figure()
    plt.imshow(load_img(df['ImagePath'].iloc[example_indices[i]], target_size=(66, 200)))
    plt.title(f"Actual: {example_angles[i]}, Predicted: {predicted_angles[i][0]:.2f}")
    plt.axis('off')
    plt.show()
# Out:
# 1/1 [==============================] - 1s 752ms/step
